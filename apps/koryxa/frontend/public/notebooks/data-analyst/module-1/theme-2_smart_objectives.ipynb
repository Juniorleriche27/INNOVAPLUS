# %% [markdown]
# # Theme 2 — Objectifs SMART & questions d’analyse
#
# Ce notebook est un support de travail.
#
# Objectifs :
# - Écrire un objectif SMART (baseline, cible, délai, périmètre)
# - Ajouter un garde-fou qualité
# - Définir 3–6 questions d’analyse testables
# - Écrire 2 hypothèses testables

# %% [markdown]
# ## 1) Template objectif SMART (à remplir)
#
# Remplis ce bloc, puis copie le résultat dans tes notes.
#
# **Phrase vendable :**
#
# “Augmenter / Réduire **[KPI]** de **[baseline]** à **[cible]** d’ici **[délai]**, sur **[périmètre]**, sans dégrader **[garde-fou]**.”

# %%
# Remplis les champs ci-dessous
kpi = ""
baseline = ""
target = ""
deadline = ""
scope = ""
guardrail = ""

smart = (
    f"Augmenter / Réduire {kpi} de {baseline} à {target} d’ici {deadline}, "
    f"sur {scope}, sans dégrader {guardrail}."
)
smart

# %% [markdown]
# ## 2) Questions d’analyse (3–6)
#
# Structure recommandée :
# - Descriptive : où en est-on ?
# - Diagnostic : pourquoi ?
# - Segmentation : qui est le plus concerné ?
# - Parcours/Funnel : où ça bloque ?
# - Leviers : qu’est-ce qui change si on fait X ?

# %%
questions = [
    "",
    "",
    "",
]

# Affiche proprement
for i, q in enumerate([q for q in questions if q.strip()], start=1):
    print(f"{i}. {q}")

# %% [markdown]
# ## 3) Hypothèses testables (2)
#
# Une hypothèse testable = variable mesurable + période + direction attendue.
#
# Exemples :
# - "Les apprenants qui ouvrent le notebook dans les 48h ont un taux de complétion supérieur."
# - "Le drop est concentré sur la page X (trop dense / manque d’exemples)."

# %%
hypotheses = [
    "",
    "",
]

for i, h in enumerate([h for h in hypotheses if h.strip()], start=1):
    print(f"H{i}: {h}")

# %% [markdown]
# ## 4) Export (optionnel)
#
# Tu peux exporter tes réponses dans un fichier texte si tu veux garder une preuve.

# %%
content = []
content.append("# Theme 2 — Objectif SMART\n")
content.append(smart + "\n\n")
content.append("# Questions d’analyse\n")
for i, q in enumerate([q for q in questions if q.strip()], start=1):
    content.append(f"{i}. {q}\n")
content.append("\n# Hypothèses\n")
for i, h in enumerate([h for h in hypotheses if h.strip()], start=1):
    content.append(f"H{i}: {h}\n")

with open("theme2_smart_objective.md", "w", encoding="utf-8") as f:
    f.write("".join(content))

print("✅ Export generated: theme2_smart_objective.md")
