# %% [markdown]
# # KPI Dictionary Validator
#
# Remplis un mini dictionnaire KPI et exporte le CSV.
# Sortie attendue : module1_kpi_dictionary.csv

# %%
import pandas as pd

data = [
    {
        "kpi": "Completion_Rate_M1",
        "definition": "% d'inscrits ayant complete le module 1",
        "formula": "completed_users / total_enrolled",
        "granularity": "cohort_week",
        "source": "events.csv"
    },
    {
        "kpi": "Active_Users_7d",
        "definition": "Utilisateurs actifs sur 7 jours",
        "formula": "unique users with events in last 7d",
        "granularity": "week",
        "source": "events.csv"
    }
]

df = pd.DataFrame(data)
df.to_csv("module1_kpi_dictionary.csv", index=False)
